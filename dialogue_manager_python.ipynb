# %%
#TODO 
# - Need to keep http links 
# - Need to weight best answers based on distance, number of matching words, Levenshtein distance,

# %%
import os 
import numpy as np
import pandas as pd
from pathlib import Path
import csv
import pickle
import nmslib
import annoy
from datetime import datetime
from collections import defaultdict
from IPython.display import FileLink
import sqlite3
DB_NAME = 'StackOverflow_python.db'


connection = sqlite3.connect(DB_NAME)
c = connection.cursor()


DATA_PATH = Path('data/')
MODEL_PATH = Path('models/')
FLASK_PATH = Path('ui')
FLASK_PATH.mkdir(exist_ok=True)

# %%
# utils file 

import nltk
import pickle
import re
import numpy as np
import html

from nltk.corpus import stopwords
stopwords_set = set(stopwords.words('english'))


def avg_word_vectors(question, embeddings, dim):
    words_embedding = [embeddings[word] for word in question.lower().split() if word in embeddings]
    if not words_embedding:
        return np.zeros(dim)
    words_embedding = np.array(words_embedding).astype(np.float32)
    return words_embedding.mean(axis=0)

def average_tfidf_vectors(question, embeddings, dim, vect, idf_scores):
    # get idf weights
    split_question = [word for word in question.lower().split() if word in embeddings]
    if not split_question:
        return np.zeros(dim).astype(np.float32)
    words_embedding = np.zeros((dim, len(split_question))).astype(np.float32)
    for i, token in enumerate(split_question):
        if token in embeddings:
            embed_score = embeddings[token]
        else: embed_score = 0
        idf_score = idf_scores[token]
        # word vectors multiply by their TF-IDF scores
        words_embedding[:, i] = embed_score * idf_score    
    return words_embedding.mean(axis=1)


def get_embeddings(filename):
    embeddings = {}
    with open(MODEL_PATH/filename, newline='') as f:
        reader = csv.reader(f, delimiter='\t')
        embed_list = list(reader)
    for line in embed_list:
        embeddings[line[0]] = np.asarray(line[1:], dtype=np.float32)
        
    dim = len(embeddings['code'])
    return embeddings, dim


def unpickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)



re1 = re.compile(r'  +')
# def clean_title(text, remove_html=False, other=False):
def clean_text(text, remove_html=False, other=False):
    
    replace_by_space_re = re.compile('[/(){}\[\]\|@,;]')
    bad_symbols_re = re.compile('[^0-9a-z #+_]')
    
    if remove_html:
        x = re.sub(r'<code>[^>]*</code>', '', text)
        x = re.sub(r'<[^>]*>', '', x)
        x = re.sub(r'[^A-Za-z0-9]', ' ', x)
    text = text.lower()
    text = text.replace('π', 'pi').replace('#39;', "'").replace('amp;', '&').replace('#146;', "'").replace(
            'nbsp;', ' ').replace('#36;', '$').replace('\\n', "\n").replace('quot;', "'").replace(
            '<br />', "\n").replace('\\"', '').replace('<unk>','u_n').replace(' @.@ ','.').replace(
            ' @-@ ','-').replace('\\', ' \\ ').replace('"',"'").replace('\n', ' ').replace('\r', ' ')
    text = replace_by_space_re.sub(' ', text)
    text = bad_symbols_re.sub('', text)
    text = ' '.join([x for x in text.split() if x and x not in stopwords_set])
    return re1.sub(' ', html.unescape(text).strip())


# def get_top_preds(X, clf, k=3):
#     preds = clf.predict_proba(X)
#     return np.argsort(preds)[:,::-1][0][:3]

def get_top_preds(X, clf, class_map, k=3, cutoff=0.8):
        preds = clf.predict_proba(X)
        sorted_preds = np.argsort(preds)[:,::-1][0][:3]
        top_scores = [preds[0][i] for i in sorted_preds]
        if top_scores[0] > cutoff:
            # if top_scores above threshold only need to return top 
            return [class_map[sorted_preds[0]]]
        else:
            return [class_map[p] for p in sorted_preds]

        
def merge_parent_comment(df_parent, df_comments, results, distances):
    distance_df = pd.DataFrame.from_dict(dict(zip(results, distances)), orient='index')
    distance_df.columns = ['distances']
    parent_len = len(df_parent)
    df_parent = df_parent.merge(distance_df, how='left', left_on='comment_id', right_index=True)
    assert len(df_parent) == parent_len 
    
    final_df = df_parent[['comment_id', 'comment', 'title', 'score', 'distances']].merge(
            df_comments[['parent_id', 'comment', 'score']], how='left', left_on='comment_id', right_on='parent_id', 
            suffixes=('_parent', '_comment')).dropna(subset=['comment_comment']).sort_values('distances')
    return final_df.reset_index(drop=True)


from sklearn.metrics.pairwise import linear_kernel

def tfidf_cosine_similarities(X, question, topk=5):
    tfid_vectorizer = unpickle(MODEL_PATH/'tf_idf_python_title_stopwords.pkl')

    tfidf_X = tfid_vectorizer.transform(X)
    tfidf_question = tfid_vectorizer.transform([question])

    cosine_similarities = linear_kernel(tfidf_question, tfidf_X).flatten()
    related_docs_indices = cosine_similarities.argsort()[:-topk:-1]
    print(related_docs_indices)
    return final_df.loc[related_docs_indices]


# -------------------------------------------------------------------------------------------------------------------



# with open(MODEL_PATH/'tf_idf.pkl', mode='rb') as f:
#     vect = pickle.load(f)
    
# idf_scores = defaultdict(lambda:0, zip(vect.get_feature_names(), vect.idf_))

# parent_comment_map = pickle.load((DATA_PATH/'parent_comment_map.pkl').open('rb'))


class DialogueManager(object):
    def __init__(self, data_path, model_path):
        self.model_path = model_path
        self.data_path = data_path
        self.thread_embeddings_path = model_path/'thread_embeddings_by_tags'
        self.knn_path = model_path/'knn_embeddings_path'
        self.word_embeddings, self.dim = get_embeddings('starspace_embedding100_ngram2.tsv')
        self.parent_comment_map = unpickle(data_path/'parent_comment_map.pkl')
        
#         self.tag_classifier = unpickle(model_path/'LR_tag_classifier_all.pkl')
#         self.class_map = unpickle(data_path/'class_map.pkl')
        
        self.tfid_vectorizer = unpickle(model_path/'tf_idf_python_title_stopwords.pkl')
        self.idf_scores = defaultdict(lambda:0, zip(self.tfid_vectorizer.get_feature_names(), 
                                                    self.tfid_vectorizer.idf_))
        
        self.parent_comment_map = unpickle(data_path/'parent_comment_map.pkl')
        
        
    def __get_embeddings_by_tag(self, tag):
        
#         embeddings_files = [self.thread_embeddings_path/tag for tag in tags]
#         for file in embeddings_files:
#             ids, vectors = unpickle(embeddings_files)
        
        # tfidf-avg
        tag_path = 'python_only.pkl'
        embeddings_file = self.thread_embeddings_path/tag_path
        ids, vectors = unpickle(embeddings_file)
        return ids, vectors
    
    def __create_nmslib_index(self, a, space, load=True, filepath=None, save=False):
        M = 25
        efC = 100
        
        num_threads = 4
        index_time_params = {'M': M, 'indexThreadQty': num_threads, 'efConstruction': efC, 
                             'post': 0, 'skip_optimized_index':1}
        query_time_params = {'efSearch': efC}

        index = nmslib.init(space=space)
        if load:
            # only need to init if indexed is saved
            index.loadIndex(filepath)
#             index.setQueryTimeParams(query_time_params)
            return index
        else:
            index.addDataPointBatch(a)
            index.createIndex()
#             index.setQueryTimeParams(query_time_params)
            if save: index.saveIndex(filepath)
            return index
        
    def __create_annoy_index(self, data, space='angular', n_trees=30, load=True, filepath=None, save=False):
                
        index = annoy.AnnoyIndex(self.dim, metric=space)
        if load:
            # only need to init if indexed is saved
            index.load(filepath)
        else:
            for i, vect in enumerate(data):
                index.add_item(i, vect)
            index.build(n_trees)            
            if save: index.save(filepath)
        return index

    
    def get_similar(self, question, question_to_vec=average_tfidf_vectors, topk=5, space='angular', 
                    load=True, save=False, return_dist=True, *args, **kwargs):
        
#         tags = self.get_tags(question)
        # need to update for multiple tags
#         tag = tags[0]
        print('get vects')
        start = datetime.now()
#         tag
        thread_ids, thread_vectors = self.__get_embeddings_by_tag(tag=None)
#         candidate2vecs = np.load(MODEL_PATH/'candidate2vecs_python_title.npy')
        print(datetime.now() - start)
        print('create index')
        start = datetime.now()
#         tag_path = tag + '.bin'
#         tag_path = 'python_only.bin'
        tag_path = 'python_only.annoy'
#         index = self.__create_nmslib_index(thread_vectors, space=space, load=load, 
#                                            filepath=str(self.knn_path/tag_path), save=save)
        index = self.__create_annoy_index(thread_vectors, space=space, load=load, 
                                           filepath=str(self.knn_path/tag_path), save=save)
        print(datetime.now() - start)
        print('question creation')

        question2vec = question_to_vec(question, self.word_embeddings, self.dim, vect=self.tfid_vectorizer, 
                                        idf_scores=self.idf_scores, *args, **kwargs)
        print('query')
        start = datetime.now()
#         idxs, distances = index.knnQuery([question2vec], k=topk)
        idxs, distances = index.get_nns_by_vector(question2vec, n=topk, include_distances=return_dist)
        print(datetime.now() - start)
        output = [thread_ids[i] for i in idxs]
        if return_dist: output = output, distances
        return output
    
    
    def get_comments(self, post_ids):
        # need to weight by distance 
        # need to get for multiple tags, combine and weight by distance
        df_parent = self.get_df(np.array(post_ids).flatten().tolist())

        knns = [j for i in post_ids if i in self.parent_comment_map for j in self.parent_comment_map[i]]
        df_comments = self.get_df(knns)

        return df_parent, df_comments 
    
    def get_tags(self, question, k=3): 
        cleaned_question = clean_text(question)
        features = self.tfid_vectorizer.transform([cleaned_question])
        preds = get_top_preds(features, self.tag_classifier, self.class_map, k)
        return preds
    
    def clean_output(self, df):
        # get rid of bad (negative / 0 scores)
        # only show good comments (based on distance?)
        # clean html
        # print in cool format
        pass
    
    def merge_parent_comment(self, df_parent, df_comments, results, distances):
        distance_df = pd.DataFrame.from_dict(dict(zip(results, distances)), orient='index')
        distance_df.columns = ['distances']
        parent_len = len(df_parent)
        df_parent = df_parent.merge(distance_df, how='left', left_on='comment_id', right_index=True)
        assert len(df_parent) == parent_len 

        final_df = df_parent[['comment_id', 'comment', 'title', 'score', 'distances']].merge(
                df_comments[['parent_id', 'comment', 'score']], how='left', left_on='comment_id', right_on='parent_id', 
                suffixes=('_parent', '_comment')).dropna(subset=['comment_comment']).sort_values('distances')
        return final_df.reset_index(drop=True)

    def get_df(self, ids):
        neighbor_length = '?,' * len(ids)
        df = pd.read_sql("SELECT * FROM posts WHERE comment_id IN ({})".format(neighbor_length[:-1]), 
                                         connection, params=tuple(ids))
        return df

# %%
# %%time
dm = DialogueManager(DATA_PATH, MODEL_PATH)
# Out:
# CPU times: user 17.2 s, sys: 1.63 s, total: 18.8 s
# Wall time: 18.8 s

# %%
question = 'How do you implement logistic regression in python?'
clean_question = clean_text(question)

results, distances = dm.get_similar(clean_question, topk=100, load=True, save=False, return_dist=True)
print(list(zip(results, distances)))
df_parent, df_comments = dm.get_comments(results)
final_df = dm.merge_parent_comment(df_parent, df_comments, results, distances)
final_df.head()
# Out:
# get vects
# 0:00:00.495709
# create index
# 0:00:00.899871
# question creation
# query
# 0:00:00.001123
# [(47278604, 0.1676356941461563), (37391923, 0.3394250273704529), (38621685, 0.3394250273704529), (40223553, 0.3394250273704529), (40865717, 0.3394250273704529), (46349963, 0.3394250273704529), (48962697, 0.3394250273704529), (20328835, 0.34385648369789124), (14262755, 0.3649623394012451), (40251587, 0.3673402667045593), (49135107, 0.3728841543197632), (46999321, 0.4175085425376892), (33616265, 0.41781094670295715), (40070064, 0.42642542719841003), (45590515, 0.42642542719841003), (45705490, 0.4515378773212433), (47728309, 0.45285671949386597), (30499018, 0.464110791683197), (41926679, 0.46783876419067383), (43426454, 0.4716132879257202), (40051478, 0.4758162498474121), (24154466, 0.4758162498474121), (46588190, 0.4840378761291504), (13794754, 0.487010657787323), (37031276, 0.49025967717170715), (34302840, 0.49104371666908264), (50283653, 0.4915216863155365), (24935415, 0.49579480290412903), (17105154, 0.4972977042198181), (12038259, 0.501002848148346), (32724678, 0.5075072646141052), (47121953, 0.5098010301589966), (43663967, 0.5098749399185181), (39605746, 0.514021635055542), (34342393, 0.5140216946601868), (34362125, 0.5140216946601868), (47841637, 0.5177914500236511), (33002621, 0.5197854042053223), (34033189, 0.5207597017288208), (12146914, 0.5225364565849304), (23339416, 0.5231833457946777), (44694867, 0.5243866443634033), (26528019, 0.5272247791290283), (40035561, 0.5287910103797913), (40647639, 0.5293601751327515), (26593231, 0.5318318605422974), (46738958, 0.5319241881370544), (49493468, 0.5331666469573975), (28568623, 0.5348353981971741), (50350816, 0.5367928147315979), (41569858, 0.5387497544288635), (44888950, 0.5423572659492493), (36051506, 0.5431029200553894), (46701530, 0.5444614887237549), (46575392, 0.5462677478790283), (3754051, 0.5493671894073486), (41959431, 0.5497021675109863), (48202410, 0.5515478253364563), (36742032, 0.5545143485069275), (45157944, 0.5566869378089905), (42669736, 0.5574823617935181), (41398541, 0.5581702589988708), (48508127, 0.5598751306533813), (36303141, 0.560263454914093), (46043412, 0.5637123584747314), (40067172, 0.5660429000854492), (47905139, 0.5680066347122192), (50086930, 0.5680066347122192), (41065534, 0.568554699420929), (47137908, 0.5690341591835022), (41159733, 0.5700204968452454), (37359790, 0.5705780386924744), (38365341, 0.5718362331390381), (47467196, 0.5719165205955505), (49819504, 0.5732751488685608), (12157881, 0.5735992193222046), (45653712, 0.5735992193222046), (37054349, 0.5776332020759583), (49860809, 0.5782730579376221), (36760000, 0.5810207724571228), (18540738, 0.5813327431678772), (47845610, 0.5822253823280334), (27558067, 0.583202064037323), (43431236, 0.5841603875160217), (50547709, 0.5873264074325562), (34871535, 0.5889360904693604), (50508519, 0.5924013257026672), (39984982, 0.5928180813789368), (47818121, 0.5933024883270264), (42991196, 0.5933597683906555), (50428825, 0.5933685302734375), (45960069, 0.5946488976478577), (39444955, 0.5949012637138367), (20869711, 0.5959169268608093), (47243202, 0.5971040725708008), (50414480, 0.5997307300567627), (46286669, 0.6018503308296204), (29953338, 0.6022591590881348), (44961016, 0.602415144443512), (31563789, 0.604072093963623)]
#    comment_id                                     comment_parent  \
# 0    47278604  <p>I am applying multiple ML algorithm to this...
# 1    48962697  <p>I created a simple Logistic Regression mode...
# 2    46349963  <p>I'm trying to build a Logistic regression m...
# 3    37391923  <p>I am currently doing the Logistic Regressio...
# 4    37391923  <p>I am currently doing the Logistic Regressio...
#
#                                     title  score_parent  distances  \
# 0           Implement Logistic Regression             0   0.167636
# 1  Chainer - Python - Logistic Regression             0   0.339425
# 2           Logistic Regression in Python             0   0.339425
# 3           Logistic Regression in python             0   0.339425
# 4           Logistic Regression in python             0   0.339425
#
#     parent_id                                    comment_comment  \
# 0  47278604.0  <p><code>predict</code> returns log-odds for a...
# 1  48962697.0  <p>At first what is your main question? The be...
# 2  46349963.0  <p>You can just use a linear function as activ...
# 3  37391923.0  <p>I think it will be more easily, when you po...
# 4  37391923.0  <p>The Predict method as mentioned in the scik...
#
#    score_comment
# 0            4.0
# 1            1.0
# 2            0.0
# 3            0.0
# 4            0.0

# %%
distance_df = pd.DataFrame.from_dict(dict(zip(results, distances)), orient='index')
distance_df.columns = ['distances']
distance_df
# Out:
#           distances
# 47278604   0.167636
# 37391923   0.339425
# 38621685   0.339425
# 40223553   0.339425
# 40865717   0.339425
# 46349963   0.339425
# 48962697   0.339425
# 20328835   0.343856
# 14262755   0.364962
# 40251587   0.367340
# 49135107   0.372884
# 46999321   0.417509
# 33616265   0.417811
# 40070064   0.426425
# 45590515   0.426425
# 45705490   0.451538
# 47728309   0.452857
# 30499018   0.464111
# 41926679   0.467839
# 43426454   0.471613
# 40051478   0.475816
# 24154466   0.475816
# 46588190   0.484038
# 13794754   0.487011
# 37031276   0.490260
# 34302840   0.491044
# 50283653   0.491522
# 24935415   0.495795
# 17105154   0.497298
# 12038259   0.501003
# ...             ...
# 41159733   0.570020
# 37359790   0.570578
# 38365341   0.571836
# 47467196   0.571917
# 49819504   0.573275
# 12157881   0.573599
# 45653712   0.573599
# 37054349   0.577633
# 49860809   0.578273
# 36760000   0.581021
# 18540738   0.581333
# 47845610   0.582225
# 27558067   0.583202
# 43431236   0.584160
# 50547709   0.587326
# 34871535   0.588936
# 50508519   0.592401
# 39984982   0.592818
# 47818121   0.593302
# 42991196   0.593360
# 50428825   0.593369
# 45960069   0.594649
# 39444955   0.594901
# 20869711   0.595917
# 47243202   0.597104
# 50414480   0.599731
# 46286669   0.601850
# 29953338   0.602259
# 44961016   0.602415
# 31563789   0.604072
#
# [100 rows x 1 columns]

# %%
def merge_parent_comment(df_parent, df_comments, results, distances):
    distance_df = pd.DataFrame.from_dict(dict(zip(results, distances)), orient='index')
    distance_df.columns = ['distances']
    parent_len = len(df_parent)
    df_parent = df_parent.merge(distance_df, how='left', left_on='comment_id', right_index=True)
    assert len(df_parent) == parent_len 
    
    final_df = df_parent[['comment_id', 'comment', 'title', 'score', 'distances']].merge(
            df_comments[['parent_id', 'comment', 'score']], how='left', left_on='comment_id', right_on='parent_id', 
            suffixes=('_parent', '_comment')).dropna(subset=['comment_comment']).sort_values('distances')
    return final_df.reset_index(drop=True)

final_df = merge_parent_comment(df_parent, df_comments, results, distances)
print(final_df.shape)
final_df.head()
# Out:
# (114, 8)
#    comment_id                                     comment_parent  \
# 0    47278604  <p>I am applying multiple ML algorithm to this...
# 1    48962697  <p>I created a simple Logistic Regression mode...
# 2    46349963  <p>I'm trying to build a Logistic regression m...
# 3    37391923  <p>I am currently doing the Logistic Regressio...
# 4    37391923  <p>I am currently doing the Logistic Regressio...
#
#                                     title  score_parent  distances  \
# 0           Implement Logistic Regression             0   0.167636
# 1  Chainer - Python - Logistic Regression             0   0.339425
# 2           Logistic Regression in Python             0   0.339425
# 3           Logistic Regression in python             0   0.339425
# 4           Logistic Regression in python             0   0.339425
#
#     parent_id                                    comment_comment  \
# 0  47278604.0  <p><code>predict</code> returns log-odds for a...
# 1  48962697.0  <p>At first what is your main question? The be...
# 2  46349963.0  <p>You can just use a linear function as activ...
# 3  37391923.0  <p>I think it will be more easily, when you po...
# 4  37391923.0  <p>The Predict method as mentioned in the scik...
#
#    score_comment
# 0            4.0
# 1            1.0
# 2            0.0
# 3            0.0
# 4            0.0

# %%
from sklearn.metrics.pairwise import linear_kernel

def tfidf_cosine_similarities(X, question, topk=5):
    tfid_vectorizer = unpickle(MODEL_PATH/'tf_idf_python_title_stopwords.pkl')

    tfidf_X = tfid_vectorizer.transform(X)
    tfidf_question = tfid_vectorizer.transform([question])

    cosine_similarities = linear_kernel(tfidf_question, tfidf_X).flatten()
    related_docs_indices = cosine_similarities.argsort()[:-topk:-1]
    print(related_docs_indices)
    return final_df.loc[related_docs_indices]


tfidf_cosine_similarities(final_df['comment_parent'], question)
# Out:
# [38 87 86 19]
#     comment_id                                     comment_parent  \
# 38    33002621  <p>I am compiling the framework for a logistic...
# 87    49860809  <h2>I used logistic regression with python and...
# 86    49860809  <h2>I used logistic regression with python and...
# 19    30499018  <p>According to what I have understood linear ...
#
#                                                 title  score_parent  \
# 38                      Logistic Regression Framework             0
# 87  how do I find the actual logistic regression m...             1
# 86  how do I find the actual logistic regression m...             1
# 19  Difference between linear and logistic regress...             4
#
#     distances   parent_id                                    comment_comment  \
# 38   0.519785  33002621.0  <p>Most of your questions can be addressed by ...
# 87   0.578273  49860809.0  <p>I'm assuming you're using SkLearn. But what...
# 86   0.578273  49860809.0  <p>The <code>model</code> object has an attrib...
# 19   0.464111  30499018.0  <p>There is a strict link between linear regre...
#
#     score_comment
# 38            1.0
# 87            0.0
# 86            2.0
# 19            6.0

# %%
from fuzzyset import FuzzySet

# Levenshtein distance
    
def num_matching_words(query, df):
    f = FuzzySet()
    for title, comment_parent, comment_comment in zip(df['title'], df['comment_parent'], df['comment_comment']):
        f.add(title + ' ' + comment_parent + ' ' + comment_comment)
#         f.add(clean_text(comment_parent))
    return f.use_levenshtein(query)
    

print(question)
print(num_matching_words(question, final_df))
# Out:
# How do you implement logistic regression in python?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-201-1ddec78d61ae> in <module>()
#      12
#      13 print(question)
# ---> 14 print(num_matching_words(question, final_df))
#
# <ipython-input-201-1ddec78d61ae> in num_matching_words(query, df)
#       8         f.add(title + ' ' + comment_parent + ' ' + comment_comment)
#       9 #         f.add(clean_text(comment_parent))
# ---> 10     return f.use_levenshtein(query)
#      11
#      12
#
# TypeError: 'bool' object is not callable

# %%
final_df
# Out:
#      comment_id                                     comment_parent  \
# 0      47278604  <p>I am applying multiple ML algorithm to this...
# 1      48962697  <p>I created a simple Logistic Regression mode...
# 2      46349963  <p>I'm trying to build a Logistic regression m...
# 3      37391923  <p>I am currently doing the Logistic Regressio...
# 4      37391923  <p>I am currently doing the Logistic Regressio...
# 5      40865717  <p>I have been at this for a couple of hours a...
# 6      38621685  <p>I have been trying to implement logistic re...
# 7      37391923  <p>I am currently doing the Logistic Regressio...
# 8      20328835  <p>I want to implement Logisitic regression fr...
# 9      20328835  <p>I want to implement Logisitic regression fr...
# 10     14262755  <p>I have a data set as such:</p> <pre><code>0...
# 11     40251587  <p>I have created repo</p> <p><a href='https:/...
# 12     49135107  <p>I have a dataset consisting of student mark...
# 13     46999321  <p>I tried to solve a simple linear regression...
# 14     33616265  <p>I am learning Machine Learning, and so far ...
# 15     33616265  <p>I am learning Machine Learning, and so far ...
# 16     45590515  <p>I am trying to implement a logistic regress...
# 17     40070064  <p>I am trying to implement: <a href='https://...
# 18     45705490  <p>I am having some difficulties in implementi...
# 19     30499018  <p>According to what I have understood linear ...
# 20     41926679  <p>Learning something new here so I'm hoping t...
# 21     43426454  <p><em>Hello</em></p> <p>I just want to try bi...
# 22     40051478  <p>Here is the line of code. I know the issue ...
# 23     46588190  <p>I'm trying to implement vectorized logistic...
# 24     13794754  <p>I am trying to code up logistic regression ...
# 25     13794754  <p>I am trying to code up logistic regression ...
# 26     13794754  <p>I am trying to code up logistic regression ...
# 27     37031276  <p>My input data <strong>for one step</strong>...
# 28     24935415  <p>I am learning Logistic Regression from skle...
# 29     24935415  <p>I am learning Logistic Regression from skle...
# ..          ...                                                ...
# 84     37054349  <p>I would like to solve regression problem vi...
# 85     37054349  <p>I would like to solve regression problem vi...
# 86     49860809  <h2>I used logistic regression with python and...
# 87     49860809  <h2>I used logistic regression with python and...
# 88     36760000  <p>I have a test dataset and train dataset as ...
# 89     36760000  <p>I have a test dataset and train dataset as ...
# 90     18540738  <p>Trying to do logistic regression through pa...
# 91     47845610  <p>I have the following variables:</p> <pre><c...
# 92     47845610  <p>I have the following variables:</p> <pre><c...
# 93     27558067  <p>I am trying to compare the logistic regress...
# 94     27558067  <p>I am trying to compare the logistic regress...
# 95     43431236  <p>From scikit-learn's <a href='http://scikit-...
# 96     50547709  <p>i am tring to learn supervised learning in ...
# 97     34871535  <p>I'm now using the training set from OpenCla...
# 98     50508519  <p>I am sure this question may not be in the b...
# 99     39984982  <p>In scikit-learn, the C is the inverse of re...
# 100    47818121  <p>In Logistic Regression for binary classific...
# 101    42991196  <p><em>(Any better way to input markdown?)</em...
# 102    50428825  <p>When running a logistic regression, the coe...
# 103    50428825  <p>When running a logistic regression, the coe...
# 104    45960069  <p>I'm doing multiclass classification in Pyth...
# 105    39444955  <p>I have written vary basic sklearn code usin...
# 106    39444955  <p>I have written vary basic sklearn code usin...
# 107    20869711  <p>I have some problem with adding own feature...
# 108    47243202  <p>I have a X feature matrix and a y label mat...
# 109    50414480  <p>I have defined a logistic regression model ...
# 110    46286669  <p>How do I retrain my existing machine learni...
# 111    46286669  <p>How do I retrain my existing machine learni...
# 112    44961016  <p>I am new to scala and I want to implement a...
# 113    31563789  <p>I am doing Multiclass Classification and ap...
#
#                                                  title  score_parent  \
# 0                        Implement Logistic Regression             0
# 1               Chainer - Python - Logistic Regression             0
# 2                        Logistic Regression in Python             0
# 3                        Logistic Regression in python             0
# 4                        Logistic Regression in python             0
# 5                           Python Logistic Regression             0
# 6                           Logistic Regression Python             1
# 7                        Logistic Regression in python             0
# 8                     Logistic regression using python             1
# 9                     Logistic regression using python             1
# 10              Multiple Logistic Regression in Python             2
# 11     OutOfRangeError while doing logistic regression             0
# 12                   Logistic regression using Flux.jl             1
# 13                          Simple logistic regression            -4
# 14   Will logistic regression work with imblanced d...             2
# 15   Will logistic regression work with imblanced d...             2
# 16            Tensorflow: Logistic regression cost=NaN             0
# 17                      Tensorflow Logistic Regression             1
# 18                  Logistic Regression Implementation             0
# 19   Difference between linear and logistic regress...             4
# 20     logistic regression with tensorflow not working             1
# 21               tensorflow simple logistic regression             1
# 22          Simple Logistic Regression Error in Python             0
# 23                    Python Numpy Logistic Regression             0
# 24                     Logistic regression using SciPy             5
# 25                     Logistic regression using SciPy             5
# 26                     Logistic regression using SciPy             5
# 27   How to make simple logistic regression in tens...             0
# 28             Logistic Regression function on sklearn             3
# 29             Logistic Regression function on sklearn             3
# ..                                                 ...           ...
# 84                       Python, Tensorflow Regression             0
# 85                       Python, Tensorflow Regression             0
# 86   how do I find the actual logistic regression m...             1
# 87   how do I find the actual logistic regression m...             1
# 88   Python : How to use Multinomial Logistic Regre...             5
# 89   Python : How to use Multinomial Logistic Regre...             5
# 90                                Regression in Python             1
# 91                             Regression using Python             0
# 92                             Regression using Python             0
# 93   Why are the logistic regression results differ...             4
# 94   Why are the logistic regression results differ...             4
# 95   How to perform an unregularized logistic regre...             1
# 96               supervised logistic regression python             0
# 97                    Questions on Logistic Regression             0
# 98   Ordinal logistic regression how it differs fro...            -1
# 99   How to find the regularization parameter in lo...             0
# 100            Confusion Matrix in Logistic Regression             1
# 101  Negative-log-likelihood dimensions in logistic...             0
# 102  Different coefficients: scikit-learn vs statsm...             0
# 103  Different coefficients: scikit-learn vs statsm...             0
# 104  The array of predictions using Logistic Regres...             0
# 105  Using logistic regression to predict the param...             0
# 106  Using logistic regression to predict the param...             0
# 107            Features in sklearn logistic regression             1
# 108  How to get the weight vector in Logistic Regre...             3
# 109      Reshaping the output of a logistic regression             0
# 110  How to retrain logistic regression model in sk...             0
# 111  How to retrain logistic regression model in sk...             0
# 112  How to set data for logistic regression in scala?             0
# 113  Logistic Regression Scikit-Learn Getting the c...             2
#
#      distances   parent_id                                    comment_comment  \
# 0     0.167636  47278604.0  <p><code>predict</code> returns log-odds for a...
# 1     0.339425  48962697.0  <p>At first what is your main question? The be...
# 2     0.339425  46349963.0  <p>You can just use a linear function as activ...
# 3     0.339425  37391923.0  <p>I think it will be more easily, when you po...
# 4     0.339425  37391923.0  <p>The Predict method as mentioned in the scik...
# 5     0.339425  40865717.0  <p>First of all, double-check if your problem ...
# 6     0.339425  38621685.0  <p>You are not configuring the C parameter - w...
# 7     0.339425  37391923.0  <p>If I am not mistaken the 'u' is just notati...
# 8     0.343856  20328835.0  <p>In order to implement Logistic Regression, ...
# 9     0.343856  20328835.0  <p>You may want to try to translate your octav...
# 10    0.364962  14262755.0  <p>If getting the job done in R (through one o...
# 11    0.367340  40251587.0  <p>I assume you are trying to execute the logi...
# 12    0.372884  49135107.0  <p>You can use either GLM.jl (simpler) or Flux...
# 13    0.417509  46999321.0  <p>Since you've initialized your weights as ze...
# 14    0.417811  33616265.0  <p>Yes; it will work fine, so long as you have...
# 15    0.417811  33616265.0  <p>It all depends on your results. </p> <hr> <...
# 16    0.426425  45590515.0  <p>For regression it's better to use mean_squa...
# 17    0.426425  40070064.0  <p>When you train the model you are passing it...
# 18    0.451538  45705490.0  <p>You are computing the gradient in the last ...
# 19    0.464111  30499018.0  <p>There is a strict link between linear regre...
# 20    0.467839  41926679.0  <p><strong>Note:</strong> I think you're not d...
# 21    0.471613  43426454.0  <p>The function <code>tf.nn.softmax</code> exp...
# 22    0.475816  40051478.0  <pre><code>data[col_name].values.reshape(len(d...
# 23    0.484038  46588190.0  <blockquote> <p>I think there is a problem wit...
# 24    0.487011  13794754.0  <p>Your problem is that the function you are t...
# 25    0.487011  13794754.0  <p>I was facing the same issues. When I experi...
# 26    0.487011  13794754.0  <p>Here is <a href='http://mail.scipy.org/pipe...
# 27    0.490260  37031276.0  <p>Just use: </p> <pre><code>activation = tf.a...
# 28    0.495795  24935415.0  <p>I would have a look at the following on git...
# 29    0.495795  24935415.0  <p>I recently started studying LR myself, I st...
# ..         ...         ...                                                ...
# 84    0.577633  37054349.0  <p>Once you get all x (img) data, you need to ...
# 85    0.577633  37054349.0  <p>It's my fault, I have exactly this code, I ...
# 86    0.578273  49860809.0  <p>The <code>model</code> object has an attrib...
# 87    0.578273  49860809.0  <p>I'm assuming you're using SkLearn. But what...
# 88    0.581021  36760000.0  <p>You could try </p> <pre><code>LogisticRegre...
# 89    0.581021  36760000.0  <p><a href='http://scikit-learn.org/stable/mod...
# 90    0.581333  18540738.0  <p>You can't pass a formula to <code>Logit</co...
# 91    0.582225  47845610.0  <p>At the start of your line</p> <pre><code>n ...
# 92    0.582225  47845610.0  <p>The <code>return</code> statement should be...
# 93    0.583202  27558067.0  <p>I redid the R part like this:</p> <pre><cod...
# 94    0.583202  27558067.0  <p>Not sure what your data manipulations are i...
# 95    0.584160  43431236.0  <p>No, it's not like that.</p> <p>Let's have a...
# 96    0.587326  50547709.0  <p>in the link you provided, it looks like som...
# 97    0.588936  34871535.0  <p>Your code is actually fine! Here are some r...
# 98    0.592401  50508519.0  <p>Logistic regression can be considered as an...
# 99    0.592818  39984982.0  <blockquote> <p>How should I pick the right C?...
# 100   0.593302  47818121.0  <p>Logistic Regression, like other classificat...
# 101   0.593360  42991196.0  <p>You have <code>n=500k</code> samples, each ...
# 102   0.593369  50428825.0  <p>I'm not familiar with <code>statsmodel</cod...
# 103   0.593369  50428825.0  <p>Thanks to a <a href='https://www.reddit.com...
# 104   0.594649  45960069.0  <p>The description of method itself could be f...
# 105   0.594901  39444955.0  <ol> <li>You are using <strong><em>predict_pro...
# 106   0.594901  39444955.0  <p>Use following code to get predicted labels:...
# 107   0.595917  20869711.0  <p>Not quite sure about your question, but few...
# 108   0.597104  47243202.0  <p>If i understand correctly you are looking f...
# 109   0.599731  50414480.0  <p>There is <code>tf.squeeze</code> (<a href='...
# 110   0.601850  46286669.0  <p>When you use <code>fit</code> on trained mo...
# 111   0.601850  46286669.0  <p>The size of the <code>LogicsticRegression</...
# 112   0.602415  44961016.0  <p>from your code:</p> <pre><code>val lr = new...
# 113   0.604072  31563789.0  <p>As you have a multiclass case (>2 cases) an...
#
#      score_comment
# 0              4.0
# 1              1.0
# 2              0.0
# 3              0.0
# 4              0.0
# 5              1.0
# 6              0.0
# 7              0.0
# 8              1.0
# 9              2.0
# 10             0.0
# 11             0.0
# 12             3.0
# 13             1.0
# 14             1.0
# 15             1.0
# 16             0.0
# 17             0.0
# 18             0.0
# 19             6.0
# 20             1.0
# 21             2.0
# 22             0.0
# 23             1.0
# 24             4.0
# 25             0.0
# 26             2.0
# 27             1.0
# 28             0.0
# 29             8.0
# ..             ...
# 84             0.0
# 85             0.0
# 86             2.0
# 87             0.0
# 88             2.0
# 89             6.0
# 90             9.0
# 91             0.0
# 92             0.0
# 93             0.0
# 94             6.0
# 95             3.0
# 96             0.0
# 97             3.0
# 98             0.0
# 99             1.0
# 100            1.0
# 101            1.0
# 102            0.0
# 103            0.0
# 104            0.0
# 105            3.0
# 106            1.0
# 107            1.0
# 108            4.0
# 109            0.0
# 110            0.0
# 111            0.0
# 112            1.0
# 113            1.0
#
# [114 rows x 8 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA


def tfidf_cosine_similarities(df, col, question, topk=5):
#     tfid_vectorizer = unpickle(MODEL_PATH/'tf_idf_python_title_stopwords.pkl')
    tfidf_X = tfid_vectorizer.transform(df[col])
    tfidf_question = tfid_vectorizer.transform([question])

    cosine_similarities = linear_kernel(tfidf_question, tfidf_X).flatten()
    df['tfidf_' + col] = cosine_similarities
#     related_docs_indices = cosine_similarities.argsort()[:-topk:-1]
#     return df.loc[related_docs_indices]
    return df



def symbolic_ngrams(df, col, question, pca_dim=50, topk=5):
    vect = CountVectorizer(analyzer='char', ngram_range=(1, 5), min_df=10)
    X = vect.fit_transform(df[col]).todense()
    pca = PCA(pca_dim)
    pca_X = pca.fit_transform(X)
    X_test = pca.transform(vect.transform([question]).todense())
    cosine_similarities = linear_kernel(tfidf_question, tfidf_X).flatten()
#     related_docs_indices = cosine_similarities.argsort()[:-topk:-1]
    df['ngram_' + col] = cosine_similarities
#     return df.loc[related_docs_indices]
    return df

#     return df.loc[linear_kernel(X_test, pca_X).flatten().argsort()[:-topk:-1]]


def tfidf_symbolic_ngrams_cosine_similarities(df, col, question, pca_dim=50, topk=5):
    
    # tfid 
    tfid_vectorizer = unpickle(MODEL_PATH/'tf_idf_python_title_stopwords.pkl')
    tfid_vectorizer = TfidfVectorizer(token_pattern='(\S+)', min_df=3, max_df=0.9, ngram_range=(1,1))
    tfidf_X = tfid_vectorizer.fit_transform(df[col]).todense()
    
    # symbolic n-grams (1 - 5)
    vect = CountVectorizer(analyzer='char', ngram_range=(1, 5), min_df=3, max_df=0.9)
    count_X = vect.fit_transform(df[col]).todense()
    X = np.concatenate((tfidf_X, count_X), axis=1)
    
    # PCA 
    pca = PCA(pca_dim)
    pca_X = pca.fit_transform(X)
    
    # question
    tfidf_question = tfid_vectorizer.transform([question]).todense()
    count_question = vect.transform([question]).todense()
    transformed_question = np.concatenate((tfidf_question, count_question), axis=1)
    transformed_question = pca.transform(transformed_question)
    
    # cosine similarity 
    cosine_similarities = linear_kernel(transformed_question, pca_X).flatten()
#     print(cosine_similarities)?
    df['tfidf_ngram_combo_' + col] = cosine_similarities
#     related_docs_indices = cosine_similarities.argsort()[:-topk:-1]
#     return df.loc[related_docs_indices]
    return df
    
for col in ['comment_comment', 'title', 'comment_parent']:
    final_df = tfidf_cosine_similarities(final_df, col, question, topk=100)
    final_df = symbolic_ngrams(final_df, col, question, topk=100)
    final_df = tfidf_symbolic_ngrams_cosine_similarities(final_df, col, question, topk=100)
final_df
# Out:
#      comment_id                                     comment_parent  \
# 0      47278604  <p>I am applying multiple ML algorithm to this...
# 1      48962697  <p>I created a simple Logistic Regression mode...
# 2      46349963  <p>I'm trying to build a Logistic regression m...
# 3      37391923  <p>I am currently doing the Logistic Regressio...
# 4      37391923  <p>I am currently doing the Logistic Regressio...
# 5      40865717  <p>I have been at this for a couple of hours a...
# 6      38621685  <p>I have been trying to implement logistic re...
# 7      37391923  <p>I am currently doing the Logistic Regressio...
# 8      20328835  <p>I want to implement Logisitic regression fr...
# 9      20328835  <p>I want to implement Logisitic regression fr...
# 10     14262755  <p>I have a data set as such:</p> <pre><code>0...
# 11     40251587  <p>I have created repo</p> <p><a href='https:/...
# 12     49135107  <p>I have a dataset consisting of student mark...
# 13     46999321  <p>I tried to solve a simple linear regression...
# 14     33616265  <p>I am learning Machine Learning, and so far ...
# 15     33616265  <p>I am learning Machine Learning, and so far ...
# 16     45590515  <p>I am trying to implement a logistic regress...
# 17     40070064  <p>I am trying to implement: <a href='https://...
# 18     45705490  <p>I am having some difficulties in implementi...
# 19     30499018  <p>According to what I have understood linear ...
# 20     41926679  <p>Learning something new here so I'm hoping t...
# 21     43426454  <p><em>Hello</em></p> <p>I just want to try bi...
# 22     40051478  <p>Here is the line of code. I know the issue ...
# 23     46588190  <p>I'm trying to implement vectorized logistic...
# 24     13794754  <p>I am trying to code up logistic regression ...
# 25     13794754  <p>I am trying to code up logistic regression ...
# 26     13794754  <p>I am trying to code up logistic regression ...
# 27     37031276  <p>My input data <strong>for one step</strong>...
# 28     24935415  <p>I am learning Logistic Regression from skle...
# 29     24935415  <p>I am learning Logistic Regression from skle...
# ..          ...                                                ...
# 84     37054349  <p>I would like to solve regression problem vi...
# 85     37054349  <p>I would like to solve regression problem vi...
# 86     49860809  <h2>I used logistic regression with python and...
# 87     49860809  <h2>I used logistic regression with python and...
# 88     36760000  <p>I have a test dataset and train dataset as ...
# 89     36760000  <p>I have a test dataset and train dataset as ...
# 90     18540738  <p>Trying to do logistic regression through pa...
# 91     47845610  <p>I have the following variables:</p> <pre><c...
# 92     47845610  <p>I have the following variables:</p> <pre><c...
# 93     27558067  <p>I am trying to compare the logistic regress...
# 94     27558067  <p>I am trying to compare the logistic regress...
# 95     43431236  <p>From scikit-learn's <a href='http://scikit-...
# 96     50547709  <p>i am tring to learn supervised learning in ...
# 97     34871535  <p>I'm now using the training set from OpenCla...
# 98     50508519  <p>I am sure this question may not be in the b...
# 99     39984982  <p>In scikit-learn, the C is the inverse of re...
# 100    47818121  <p>In Logistic Regression for binary classific...
# 101    42991196  <p><em>(Any better way to input markdown?)</em...
# 102    50428825  <p>When running a logistic regression, the coe...
# 103    50428825  <p>When running a logistic regression, the coe...
# 104    45960069  <p>I'm doing multiclass classification in Pyth...
# 105    39444955  <p>I have written vary basic sklearn code usin...
# 106    39444955  <p>I have written vary basic sklearn code usin...
# 107    20869711  <p>I have some problem with adding own feature...
# 108    47243202  <p>I have a X feature matrix and a y label mat...
# 109    50414480  <p>I have defined a logistic regression model ...
# 110    46286669  <p>How do I retrain my existing machine learni...
# 111    46286669  <p>How do I retrain my existing machine learni...
# 112    44961016  <p>I am new to scala and I want to implement a...
# 113    31563789  <p>I am doing Multiclass Classification and ap...
#
#                                                  title  score_parent  \
# 0                        Implement Logistic Regression             0
# 1               Chainer - Python - Logistic Regression             0
# 2                        Logistic Regression in Python             0
# 3                        Logistic Regression in python             0
# 4                        Logistic Regression in python             0
# 5                           Python Logistic Regression             0
# 6                           Logistic Regression Python             1
# 7                        Logistic Regression in python             0
# 8                     Logistic regression using python             1
# 9                     Logistic regression using python             1
# 10              Multiple Logistic Regression in Python             2
# 11     OutOfRangeError while doing logistic regression             0
# 12                   Logistic regression using Flux.jl             1
# 13                          Simple logistic regression            -4
# 14   Will logistic regression work with imblanced d...             2
# 15   Will logistic regression work with imblanced d...             2
# 16            Tensorflow: Logistic regression cost=NaN             0
# 17                      Tensorflow Logistic Regression             1
# 18                  Logistic Regression Implementation             0
# 19   Difference between linear and logistic regress...             4
# 20     logistic regression with tensorflow not working             1
# 21               tensorflow simple logistic regression             1
# 22          Simple Logistic Regression Error in Python             0
# 23                    Python Numpy Logistic Regression             0
# 24                     Logistic regression using SciPy             5
# 25                     Logistic regression using SciPy             5
# 26                     Logistic regression using SciPy             5
# 27   How to make simple logistic regression in tens...             0
# 28             Logistic Regression function on sklearn             3
# 29             Logistic Regression function on sklearn             3
# ..                                                 ...           ...
# 84                       Python, Tensorflow Regression             0
# 85                       Python, Tensorflow Regression             0
# 86   how do I find the actual logistic regression m...             1
# 87   how do I find the actual logistic regression m...             1
# 88   Python : How to use Multinomial Logistic Regre...             5
# 89   Python : How to use Multinomial Logistic Regre...             5
# 90                                Regression in Python             1
# 91                             Regression using Python             0
# 92                             Regression using Python             0
# 93   Why are the logistic regression results differ...             4
# 94   Why are the logistic regression results differ...             4
# 95   How to perform an unregularized logistic regre...             1
# 96               supervised logistic regression python             0
# 97                    Questions on Logistic Regression             0
# 98   Ordinal logistic regression how it differs fro...            -1
# 99   How to find the regularization parameter in lo...             0
# 100            Confusion Matrix in Logistic Regression             1
# 101  Negative-log-likelihood dimensions in logistic...             0
# 102  Different coefficients: scikit-learn vs statsm...             0
# 103  Different coefficients: scikit-learn vs statsm...             0
# 104  The array of predictions using Logistic Regres...             0
# 105  Using logistic regression to predict the param...             0
# 106  Using logistic regression to predict the param...             0
# 107            Features in sklearn logistic regression             1
# 108  How to get the weight vector in Logistic Regre...             3
# 109      Reshaping the output of a logistic regression             0
# 110  How to retrain logistic regression model in sk...             0
# 111  How to retrain logistic regression model in sk...             0
# 112  How to set data for logistic regression in scala?             0
# 113  Logistic Regression Scikit-Learn Getting the c...             2
#
#      distances   parent_id                                    comment_comment  \
# 0     0.167636  47278604.0  <p><code>predict</code> returns log-odds for a...
# 1     0.339425  48962697.0  <p>At first what is your main question? The be...
# 2     0.339425  46349963.0  <p>You can just use a linear function as activ...
# 3     0.339425  37391923.0  <p>I think it will be more easily, when you po...
# 4     0.339425  37391923.0  <p>The Predict method as mentioned in the scik...
# 5     0.339425  40865717.0  <p>First of all, double-check if your problem ...
# 6     0.339425  38621685.0  <p>You are not configuring the C parameter - w...
# 7     0.339425  37391923.0  <p>If I am not mistaken the 'u' is just notati...
# 8     0.343856  20328835.0  <p>In order to implement Logistic Regression, ...
# 9     0.343856  20328835.0  <p>You may want to try to translate your octav...
# 10    0.364962  14262755.0  <p>If getting the job done in R (through one o...
# 11    0.367340  40251587.0  <p>I assume you are trying to execute the logi...
# 12    0.372884  49135107.0  <p>You can use either GLM.jl (simpler) or Flux...
# 13    0.417509  46999321.0  <p>Since you've initialized your weights as ze...
# 14    0.417811  33616265.0  <p>Yes; it will work fine, so long as you have...
# 15    0.417811  33616265.0  <p>It all depends on your results. </p> <hr> <...
# 16    0.426425  45590515.0  <p>For regression it's better to use mean_squa...
# 17    0.426425  40070064.0  <p>When you train the model you are passing it...
# 18    0.451538  45705490.0  <p>You are computing the gradient in the last ...
# 19    0.464111  30499018.0  <p>There is a strict link between linear regre...
# 20    0.467839  41926679.0  <p><strong>Note:</strong> I think you're not d...
# 21    0.471613  43426454.0  <p>The function <code>tf.nn.softmax</code> exp...
# 22    0.475816  40051478.0  <pre><code>data[col_name].values.reshape(len(d...
# 23    0.484038  46588190.0  <blockquote> <p>I think there is a problem wit...
# 24    0.487011  13794754.0  <p>Your problem is that the function you are t...
# 25    0.487011  13794754.0  <p>I was facing the same issues. When I experi...
# 26    0.487011  13794754.0  <p>Here is <a href='http://mail.scipy.org/pipe...
# 27    0.490260  37031276.0  <p>Just use: </p> <pre><code>activation = tf.a...
# 28    0.495795  24935415.0  <p>I would have a look at the following on git...
# 29    0.495795  24935415.0  <p>I recently started studying LR myself, I st...
# ..         ...         ...                                                ...
# 84    0.577633  37054349.0  <p>Once you get all x (img) data, you need to ...
# 85    0.577633  37054349.0  <p>It's my fault, I have exactly this code, I ...
# 86    0.578273  49860809.0  <p>The <code>model</code> object has an attrib...
# 87    0.578273  49860809.0  <p>I'm assuming you're using SkLearn. But what...
# 88    0.581021  36760000.0  <p>You could try </p> <pre><code>LogisticRegre...
# 89    0.581021  36760000.0  <p><a href='http://scikit-learn.org/stable/mod...
# 90    0.581333  18540738.0  <p>You can't pass a formula to <code>Logit</co...
# 91    0.582225  47845610.0  <p>At the start of your line</p> <pre><code>n ...
# 92    0.582225  47845610.0  <p>The <code>return</code> statement should be...
# 93    0.583202  27558067.0  <p>I redid the R part like this:</p> <pre><cod...
# 94    0.583202  27558067.0  <p>Not sure what your data manipulations are i...
# 95    0.584160  43431236.0  <p>No, it's not like that.</p> <p>Let's have a...
# 96    0.587326  50547709.0  <p>in the link you provided, it looks like som...
# 97    0.588936  34871535.0  <p>Your code is actually fine! Here are some r...
# 98    0.592401  50508519.0  <p>Logistic regression can be considered as an...
# 99    0.592818  39984982.0  <blockquote> <p>How should I pick the right C?...
# 100   0.593302  47818121.0  <p>Logistic Regression, like other classificat...
# 101   0.593360  42991196.0  <p>You have <code>n=500k</code> samples, each ...
# 102   0.593369  50428825.0  <p>I'm not familiar with <code>statsmodel</cod...
# 103   0.593369  50428825.0  <p>Thanks to a <a href='https://www.reddit.com...
# 104   0.594649  45960069.0  <p>The description of method itself could be f...
# 105   0.594901  39444955.0  <ol> <li>You are using <strong><em>predict_pro...
# 106   0.594901  39444955.0  <p>Use following code to get predicted labels:...
# 107   0.595917  20869711.0  <p>Not quite sure about your question, but few...
# 108   0.597104  47243202.0  <p>If i understand correctly you are looking f...
# 109   0.599731  50414480.0  <p>There is <code>tf.squeeze</code> (<a href='...
# 110   0.601850  46286669.0  <p>When you use <code>fit</code> on trained mo...
# 111   0.601850  46286669.0  <p>The size of the <code>LogicsticRegression</...
# 112   0.602415  44961016.0  <p>from your code:</p> <pre><code>val lr = new...
# 113   0.604072  31563789.0  <p>As you have a multiclass case (>2 cases) an...
#
#      score_comment  tfidf_comment_comment  ngram_comment_comment  \
# 0              4.0               0.279356               0.248157
# 1              1.0               0.000000               0.100467
# 2              0.0               0.000000               0.074215
# 3              0.0               0.000000               0.221597
# 4              0.0               0.000000               0.221597
# 5              1.0               0.058089               0.000000
# 6              0.0               0.000000               0.161612
# 7              0.0               0.000000               0.221597
# 8              1.0               0.368484               0.229025
# 9              2.0               0.166114               0.229025
# 10             0.0               0.000000               0.265309
# 11             0.0               0.217262               0.256179
# 12             3.0               0.000000               0.241264
# 13             1.0               0.000000               0.126051
# 14             1.0               0.000000               0.167385
# 15             1.0               0.000000               0.167385
# 16             0.0               0.107176               0.177897
# 17             0.0               0.000000               0.000000
# 18             0.0               0.000000               0.103546
# 19             6.0               0.351761               0.492436
# 20             1.0               0.317177               0.199065
# 21             2.0               0.000000               0.093011
# 22             0.0               0.000000               0.000000
# 23             1.0               0.000000               0.260910
# 24             4.0               0.000000               0.225298
# 25             0.0               0.243372               0.225298
# 26             2.0               0.081992               0.225298
# 27             1.0               0.041670               0.000000
# 28             0.0               0.000000               0.246458
# 29             8.0               0.122424               0.246458
# ..             ...                    ...                    ...
# 84             0.0               0.110945               0.052149
# 85             0.0               0.000000               0.052149
# 86             2.0               0.000000               0.535935
# 87             0.0               0.133851               0.535935
# 88             2.0               0.000000               0.100374
# 89             6.0               0.000000               0.100374
# 90             9.0               0.071529               0.233360
# 91             0.0               0.000000               0.036086
# 92             0.0               0.000000               0.036086
# 93             0.0               0.000000               0.054272
# 94             6.0               0.000000               0.054272
# 95             3.0               0.000000               0.422689
# 96             0.0               0.000000               0.166402
# 97             3.0               0.000000               0.038622
# 98             0.0               0.390509               0.325677
# 99             1.0               0.000000               0.000000
# 100            1.0               0.000000               0.296887
# 101            1.0               0.000000               0.116064
# 102            0.0               0.000000               0.088216
# 103            0.0               0.270327               0.088216
# 104            0.0               0.000000               0.225955
# 105            3.0               0.000000               0.086593
# 106            1.0               0.391142               0.086593
# 107            1.0               0.000000               0.043404
# 108            4.0               0.000000               0.234232
# 109            0.0               0.000000               0.103830
# 110            0.0               0.449490               0.092051
# 111            0.0               0.000000               0.092051
# 112            1.0               0.147856               0.290860
# 113            1.0               0.255764               0.223685
#
#      tfidf_ngram_combo_comment_comment  tfidf_title  ngram_title  \
# 0                          2329.829127     1.000000     0.248157
# 1                         -2951.342950     0.575795     0.100467
# 2                          3678.065843     0.829932     0.074215
# 3                          2892.922842     0.829932     0.221597
# 4                          1949.986364     0.829932     0.221597
# 5                          -995.975860     0.829932     0.000000
# 6                          1714.893022     0.829932     0.161612
# 7                          1271.823543     0.829932     0.221597
# 8                           115.464275     0.793694     0.229025
# 9                          2532.404389     0.793694     0.229025
# 10                         3427.360258     0.765193     0.265309
# 11                          928.306975     0.584333     0.256179
# 12                        -2237.773026     0.806717     0.241264
# 13                         3140.148120     0.732344     0.126051
# 14                         1449.049632     0.755175     0.167385
# 15                        -1621.571583     0.755175     0.167385
# 16                         1775.781737     0.844855     0.177897
# 17                         2172.406703     0.762615     0.000000
# 18                          449.326632     0.705549     0.103546
# 19                        -3385.998288     0.673997     0.492436
# 20                          839.280532     0.699186     0.199065
# 21                        -1537.956765     0.676821     0.093011
# 22                         3650.220159     0.690704     0.000000
# 23                        -5380.541556     0.756021     0.260910
# 24                        -1180.619173     0.693763     0.225298
# 25                         2235.873915     0.693763     0.225298
# 26                        -8955.545665     0.693763     0.225298
# 27                         -530.281134     0.673901     0.000000
# 28                         1829.240562     0.669596     0.246458
# 29                        -6830.678075     0.669596     0.246458
# ..                                 ...          ...          ...
# 84                          134.538095     0.438402     0.052149
# 85                        -4246.112568     0.438402     0.052149
# 86                         3066.742650     0.593832     0.535935
# 87                         3187.700442     0.593832     0.535935
# 88                         3497.910841     0.518432     0.100374
# 89                         2380.126144     0.518432     0.100374
# 90                       -22665.967284     0.522797     0.233360
# 91                         3276.177442     0.474514     0.036086
# 92                         3315.157520     0.474514     0.036086
# 93                         -165.946823     0.573734     0.054272
# 94                         -382.241224     0.573734     0.054272
# 95                          661.713155     0.676990     0.422689
# 96                        -1133.703932     0.621675     0.166402
# 97                       -21548.391370     0.674493     0.038622
# 98                         -322.297628     0.648000     0.325677
# 99                         2043.290820     0.538001     0.000000
# 100                         147.036572     0.624542     0.296887
# 101                        2299.326021     0.682321     0.116064
# 102                        2632.734701     0.000000     0.088216
# 103                         565.627344     0.000000     0.088216
# 104                        2579.103929     0.598907     0.225955
# 105                        2414.607797     0.571983     0.086593
# 106                         -73.609724     0.571983     0.086593
# 107                         531.652571     0.611748     0.043404
# 108                         718.634018     0.511507     0.234232
# 109                         711.923412     0.605281     0.103830
# 110                        1385.862723     0.495244     0.092051
# 111                      -10023.573099     0.495244     0.092051
# 112                       -1828.342854     0.719241     0.290860
# 113                        3264.671010     0.546212     0.223685
#
#      tfidf_ngram_combo_title  tfidf_comment_parent  ngram_comment_parent  \
# 0                  20.178589              0.248157              0.248157
# 1                   8.008265              0.100467              0.100467
# 2                  24.062918              0.074215              0.074215
# 3                  24.062918              0.221597              0.221597
# 4                  24.062918              0.221597              0.221597
# 5                   6.437111              0.000000              0.000000
# 6                  13.066688              0.161612              0.161612
# 7                  24.062918              0.221597              0.221597
# 8                   5.344199              0.229025              0.229025
# 9                   5.344199              0.229025              0.229025
# 10                 29.441680              0.265309              0.265309
# 11                 -7.526403              0.256179              0.256179
# 12                -10.046965              0.241264              0.241264
# 13                  5.270924              0.126051              0.126051
# 14                 -5.700222              0.167385              0.167385
# 15                 -5.700222              0.167385              0.167385
# 16                 -9.371845              0.177897              0.177897
# 17                 -7.656399              0.000000              0.000000
# 18                 24.707740              0.103546              0.103546
# 19                -15.701457              0.492436              0.492436
# 20                 -9.201422              0.199065              0.199065
# 21                  2.161728              0.093011              0.093011
# 22                 28.879088              0.000000              0.000000
# 23                 11.459939              0.260910              0.260910
# 24                 -8.207600              0.225298              0.225298
# 25                 -8.207600              0.225298              0.225298
# 26                 -8.207600              0.225298              0.225298
# 27                 16.383788              0.000000              0.000000
# 28                -13.933265              0.246458              0.246458
# 29                -13.933265              0.246458              0.246458
# ..                       ...                   ...                   ...
# 84                  3.741399              0.052149              0.052149
# 85                  3.741399              0.052149              0.052149
# 86                 28.505444              0.535935              0.535935
# 87                 28.505444              0.535935              0.535935
# 88                  4.185284              0.100374              0.100374
# 89                  4.185284              0.100374              0.100374
# 90                 24.062918              0.233360              0.233360
# 91                  5.344199              0.036086              0.036086
# 92                  5.344199              0.036086              0.036086
# 93                -15.003884              0.054272              0.054272
# 94                -15.003884              0.054272              0.054272
# 95                 -8.566326              0.422689              0.422689
# 96                 14.951145              0.166402              0.166402
# 97                 -6.599671              0.038622              0.038622
# 98                  1.025310              0.325677              0.325677
# 99                 25.536069              0.000000              0.000000
# 100                -3.140887              0.296887              0.296887
# 101                 0.116866              0.116064              0.116064
# 102               -21.228866              0.088216              0.088216
# 103               -21.228866              0.088216              0.088216
# 104                19.031045              0.225955              0.225955
# 105               -10.569185              0.086593              0.086593
# 106               -10.569185              0.086593              0.086593
# 107               -10.072406              0.043404              0.043404
# 108                -4.041684              0.234232              0.234232
# 109                -7.415963              0.103830              0.103830
# 110                -1.913665              0.092051              0.092051
# 111                -1.913665              0.092051              0.092051
# 112                 1.342669              0.290860              0.290860
# 113               -26.058122              0.223685              0.223685
#
#      tfidf_ngram_combo_comment_parent
# 0                         7932.416314
# 1                         7249.518118
# 2                         2559.153092
# 3                         7027.858467
# 4                         7027.858467
# 5                       -50960.543671
# 6                         1144.946519
# 7                         7027.858467
# 8                         9691.134640
# 9                         9691.134640
# 10                        6295.838976
# 11                        9168.916504
# 12                        6406.358309
# 13                        5176.739819
# 14                        9189.436591
# 15                        9189.436591
# 16                      -24686.172160
# 17                       -9849.575984
# 18                        6793.942245
# 19                        9142.059739
# 20                        5897.926175
# 21                        1759.198488
# 22                        2201.404392
# 23                        5276.793851
# 24                     -140327.297184
# 25                     -140327.297184
# 26                     -140327.297184
# 27                        1237.027216
# 28                        7900.706118
# 29                        7900.706118
# ..                                ...
# 84                        7236.656562
# 85                        7236.656562
# 86                        9023.426939
# 87                        9023.426939
# 88                        5079.473921
# 89                        5079.473921
# 90                        8068.588188
# 91                        -333.196926
# 92                        -333.196926
# 93                      -19300.714032
# 94                      -19300.714032
# 95                        9308.026684
# 96                        4252.957500
# 97                       -6192.250094
# 98                        7142.967542
# 99                        8611.661191
# 100                       9149.501150
# 101                       7071.657768
# 102                      -3979.302867
# 103                      -3979.302867
# 104                       8213.952200
# 105                     -19928.530101
# 106                     -19928.530101
# 107                       1103.405799
# 108                      10179.827308
# 109                       4627.998857
# 110                       5453.404867
# 111                       5453.404867
# 112                       6339.982889
# 113                       7852.143012
#
# [114 rows x 17 columns]

# %%
symbolic_ngrams(final_df, 'comment_comment', question, topk=10)
# Out:
#     comment_id                                     comment_parent  \
# 22    40051478  <p>Here is the line of code. I know the issue ...
# 88    36760000  <p>I have a test dataset and train dataset as ...
# 2     46349963  <p>I'm trying to build a Logistic regression m...
# 39    34033189  <p>Good night, community!</p> <p>I have a simp...
# 92    47845610  <p>I have the following variables:</p> <pre><c...
# 42    12146914  <p>When we have to predict the value of a <a h...
# 91    47845610  <p>I have the following variables:</p> <pre><c...
# 86    49860809  <h2>I used logistic regression with python and...
# 69    45157944  <p>I'm following this <a href='https://www.ten...
#
#                                                 title  score_parent  \
# 22         Simple Logistic Regression Error in Python             0
# 88  Python : How to use Multinomial Logistic Regre...             5
# 2                       Logistic Regression in Python             0
# 39             sklearn Python and Logistic regression             1
# 92                            Regression using Python             0
# 42  What is the difference between linear regressi...           117
# 91                            Regression using Python             0
# 86  how do I find the actual logistic regression m...             1
# 69  coefficients of logistic regression model in t...             1
#
#     distances   parent_id                                    comment_comment  \
# 22   0.475816  40051478.0  <pre><code>data[col_name].values.reshape(len(d...
# 88   0.581021  36760000.0  <p>You could try </p> <pre><code>LogisticRegre...
# 2    0.339425  46349963.0  <p>You can just use a linear function as activ...
# 39   0.520760  34033189.0  <p>if <code>model</code> is your <code>sklearn...
# 92   0.582225  47845610.0  <p>The <code>return</code> statement should be...
# 42   0.522536  12146914.0  <p>In short: Linear Regression gives continuou...
# 91   0.582225  47845610.0  <p>At the start of your line</p> <pre><code>n ...
# 86   0.578273  49860809.0  <p>The <code>model</code> object has an attrib...
# 69   0.556687  45157944.0  <p>You can use the two methods: <code>get_vari...
#
#     score_comment
# 22            0.0
# 88            2.0
# 2             0.0
# 39            1.0
# 92            0.0
# 42            0.0
# 91            0.0
# 86            2.0
# 69            1.0

# %%
final_df.to_csv(FLASK_PATH/'final_df.csv', index=False)

# %%
from IPython.display import FileLink

# FileLink(str(FLASK_PATH/'df_parent.csv'))
FileLink(str(FLASK_PATH/'final_df.csv'))
# Out:
# /home/matt/Desktop/DataScience/NLP/MLchat/ui/final_df.csv

# %%
df_parent.to_csv(FLASK_PATH/'df_parent.csv', index=False)
df_comments.to_csv(FLASK_PATH/'df_comments.csv', index=False)

# %%
post_ids = [40251587, 49135107, 40223553]

knns = [j for i in post_ids if i in dm.parent_comment_map for j in dm.parent_comment_map[i]]
knns
# Out:
# [41124800, 49137743]

# %%
# def get_df(ids):
#         neighbor_length = '?,' * len(ids)
#         df = pd.read_sql("SELECT * FROM posts WHERE comment_id IN ({})".format(neighbor_length[:-1]), 
#                                          connection, params=tuple(ids))
#         return df
    
    
# df_parent = get_df(results)

def get_df(ids):
        neighbor_length = '?,' * len(ids)
        df = pd.read_sql("SELECT * FROM posts WHERE comment_id IN ({})".format(neighbor_length[:-1]), 
                                         connection, params=tuple(ids))
        return df
    
    

most_similar = get_df(np.array(results).flatten().tolist())
most_similar
# Out:
#    comment_id parent_id                                            comment  \
# 0       36139      None  <p>What is the best way of creating an alphabe...
# 1     6198836      None  <p>How would I sort this ? </p> <pre><code>>>>...
# 2    11620088      None  <blockquote> <p><strong>Possible Duplicate:</s...
# 3    36698259      None  <p>I would like to sort this list:</p> <p><cod...
# 4    48408866      None  <p>I have the following list of lists of strin...
#
#                                       title        date  score  \
# 0            How to sort a list of strings?  2008-08-30    321
# 1          Python sorting a list of strings  2011-06-01      1
# 2       Sorting a list of strings in Python  2012-07-23      2
# 3    Python - How to sort a list of strings  2016-04-18      0
# 4  How to sort a list of strings in Python?  2018-01-23     -3
#
#                          tags
# 0       python string sorting
# 1              python sorting
# 2       python string sorting
# 3   python sorting python-3.x
# 4  python string list sorting

# %%
knns = [7675136, 982129, 2842866, 4228494, 1733705]

neighbor_length = '?,' * len(knns)
df = pd.read_sql("SELECT * FROM posts WHERE comment_id IN ({})".format(neighbor_length[:-1]), 
                                 connection, params=tuple(knns))


df.head()
# Out:
#    comment_id parent_id                                            comment  \
# 0      982129      None  <p>I saw an <a href='https://stackoverflow.com...
# 1     1733705      None  <p>ruby code</p> <pre><code>irb(main):001:0> a...
# 2     2842866      None  <p>Say,the trailing <code>++</code> has no act...
# 3     4228494      None  <p>this code does not show me any output</p> <...
# 4     7675136      None  <p>How can I calculate the execution time in t...
#
#                                        title        date  score  \
# 0           What does __sync_synchronize do?  2009-06-11     17
# 1                      about NSMutabuleArray  2009-11-14      0
# 2                  l+l++ is the same as l+l?  2010-05-16      0
# 3                       randomized_quicksort  2010-11-19     -6
# 4  How to calculate the execution time in C?  2011-10-06      0
#
#                tags
# 0       c++ c linux
# 1  objective-c ruby
# 2        c++ syntax
# 3     c++ algorithm
# 4          c timing

# %%
score_df = df[df.score > 0]
for i in score_df.comment.values:
    print(i)
# Out:
# <p>It forces a <a href='http://en.wikipedia.org/wiki/Memory_fence' rel='nofollow noreferrer'>memory fence</a> I guess.</p>
# <p>It is a atomic builtin for <a href='http://gcc.gnu.org/onlinedocs/gcc-4.6.2/gcc/Atomic-Builtins.html' rel='noreferrer'>full memory barrier</a>.</p> <blockquote> <p>No memory operand will be moved across the operation, either forward or backward. Further, instructions will be issued as necessary to prevent the processor from speculating loads across the operation and from queuing stores after the operation.</p> </blockquote> <p>Check details on the link above.</p>
# <p>You use a NSSet to ensure uniqueness. <code>setWithArray</code> receives an array containing the objects to add to the new set. If the same object appears more than once in <em>anArray</em>, it is added only once to the returned set:</p> <pre><code>NSArray *arr = [[NSSet setWithArray: [NSArray arrayWithObjects: @'a', @'b', @'b', @'a', @'b', nil]] allObjects]; //If you want to obtain a mutable array: NSMutableArray *mutArr = [NSMutableArray arrayWithArray: arr]; </code></pre> <p><em>allObjects</em> is used to return a NSArray representation of the NSSet, and this array contains all the unique objects in the initial array.</p>
# <p><code>l+l++</code> is undefined. There is no sequence point in your expression to separate the access to <code>l</code> and the post-increment. It can do anything, including having the same effects as <code>l+l</code>.</p> <p>EDIT: the question and answers at <a href='https://stackoverflow.com/questions/1860461/why-is-i-i-1-unspecified-behavior'>Why is `i = ++i + 1` unspecified behavior?</a> explain what a sequence point is, quote the relevant parts of the standard and provide links. Let me quote again:</p> <blockquote> <p>Except where noted, the order of evaluation of operands of individual operators and subexpressions of individual expressions, and the order in which side effects take place, is unspecified. 53) Between the previous and next sequence point a scalar object shall have its stored value modified at most once by the evaluation of an expression. <strong>Furthermore, the prior value shall be accessed only to determine the value to be stored.</strong></p> </blockquote> <p>Emphasis mine.</p> <p>SECOND EDIT: By popular request, the next sentence in the paragraph:</p> <blockquote> <p>The requirements of this paragraph shall be met for each allowable ordering of the subexpressions of a full expression; otherwise the behavior is undefined.</p> </blockquote>
# <p>The program gets stuck in the call to <code>partition(2, 4)</code>. The relevant part of the array is <code>6, 9, 7</code> at the time, so <code>pivot</code> get initialized to <code>6</code>.</p> <p>You enter the main <code>while</code> loop, and the <code>i</code> loop terminates immediately, as it always does the first time around, because <code>a[i] == pivot</code>. So you enter the <code>j</code> loop, which executes twice because <code>7</code> and <code>9</code> are both greater than <code>pivot</code>, which is still <code>6</code>. The <code>j</code> loop terminates when <code>j == 2</code> because <code>a[j] == pivot</code>.</p> <p>Moving along, the first conditional is <code>false</code> because <code>i</code> is not greater than <code>j</code>. The second conditional is <code>false</code> because <code>i</code> is not less than <code>j</code>. That marks the end of the main <code>while</code> loop, so we check the loop's condition and find that it's <code>true</code> because <code>i</code> is equal to <code>j</code>. We haven't changed any of the array elements' values, so the inner <code>while</code> loops never run again, and the conditionals remain <code>false</code>. You get stuck in an infinite loop, never making any progress.</p> <p>Take a closer look at your textbook. Either there's a mistake in the book, or you made a mistake transcribing it.</p>
# <p>Because you don't have adequate format strings for them, you need something starting with a '%', like:</p> <pre><code>printf(' Time :%d ', clock() ); </code></pre>
# <p>n_procs is never initialized, the 16372-value that gets printed just happens to be what was previously on the stack.</p> <p>The C standard library doesn't provide functionality to query processor count or high-performance timers, so you will have to look at other means of querying this. For instance, both POSIX and Windows API provides functionality like this.</p> <p>edit: See <a href='https://stackoverflow.com/questions/150355/programmatically-find-the-number-of-cores-on-a-machine'>Programmatically find the number of cores on a machine</a> for how to initialize n_procs. Seeing how you use gettimeofday, you're probably on some unix-variant; 'n_procs = sysconf(_SC_NPROCESSORS_ONLN);' is probably what you want.</p>
# <p>Try this:</p> <pre><code>printf(' Time : %lu ', clock() ); printf(' Start Time : %lds %ldus ', tv1.tv_sec, tv1.tv_usec); printf(' End Time : %lds %ldus ', tv2.tv_sec, tv2.tv_usec); </code></pre> <p>And for:</p> <pre><code>double timeval_subtract (result, x, y) </code></pre> <p>use the following to return the time difference in micro seconds:</p> <pre><code>long timeval_subtract (struct timeval * result, struct timeval * x, struct timeval * y) { long usec = x->tv_sec * 1000000L + x->tv_usec; usec -= (y->tv_sec * 1000000L + y->tv_usec); result->tv_sec = usec / 1000000L; result->tv_usec = usec % 1000000L; return usec; } </code></pre> <p>Depending on the difference of the two dates <code>x</code> and <code>y</code> the return value of the function <code>timeval_subtract</code> (not the value represented by <code>result</code>!) might be wrong, due to an overflow.</p> <p>Assuming a long is 32bit wide this overflow will occur with differences larger than 4294s, for a long having 64bit (which should be the case an 64bit machines) the overflow whould occur after much later ... ;-)</p>

# %%
# %%time
dm.get_similar('Compressing / Decompressing Folders & Files', load=True, save=False, vect=vect)
# Out:
# get vects
# Check failed: input
# 0:00:00.292297
# create index
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <timed eval> in <module>()
#
# <ipython-input-125-c0a3e2a235a1> in get_similar(self, question, question_to_vec, topk, space, load, save, return_dist, *args, **kwargs)
#     166         tag_path = tag + '.bin'
#     167         index = self.__create_nmslib_index(thread_vectors, space=space, load=load,
# --> 168                                            filepath=str(self.knn_path/tag_path), save=save)
#     169         print(datetime.now() - start)
#     170         print('question creation')
#
# <ipython-input-125-c0a3e2a235a1> in __create_nmslib_index(self, a, space, load, filepath, save)
#     141         if load:
#     142             # only need to init if indexed is saved
# --> 143             index.loadIndex(filepath)
#     144 #             index.setQueryTimeParams(query_time_params)
#     145             return index
#
# RuntimeError: Check failed: Cannot open file 'models/knn_embeddings_path/c#.bin' for reading

# %%
# %%time
dm.get_similar('How do I calculate someones age in C', 'c', load=True, save=False, vect=vect)

# %%
results[0]
# Out:
# [25642565, 50661263, 44366395, 50656792, 50646159]

# %%
# from torch.nn import CosineSimilarity
# import torch 
# # need to change / test for NOT CUDA 
# def get_similar2(self, question, tag, question_to_vec=avg_word_vectors, topk=5, return_score=False, *args, **kwargs):

#     thread_ids, thread_vectors = self.__get_embeddings_by_tag(tag)
#     cos = CosineSimilarity(dim=1)
#     question2vec = question_to_vec(question, self.word_embeddings, self.dim, *args, **kwargs)
#     output = cos(torch.Tensor(question2vec.reshape(1, -1)).cuda(), torch.Tensor(thread_vectors).cuda())
#     output = output.cpu().numpy()
#     data = [(i, thread_ids[i]) for i in range(len(output))] 
#     if return_score:
#         output = [(x, score) for score, x in sorted(zip(output, data), key=lambda pair: pair[0], reverse=True)]
#     else:
#         output = [x for _, x in sorted(zip(output, data), key=lambda pair: pair[0], reverse=True)]
#     if topk: return output[:topk]
#     else: return output

# %%
# %%time
dm.get_similar('How do I calculate someones age in C', 'c', load=False, save=True, vect=vect, return_dist=True)
# Out:
# get vects
# 0:00:02.558332
# create index
# 0:04:49.197026
# question creation
# query
# 0:00:00.001622
# CPU times: user 30min 31s, sys: 24.7 s, total: 30min 55s
# Wall time: 4min 52s
# ([5157079, 50660067, 50657512, 50661696, 50656291],
#  array([0.8260471 , 0.89971733, 0.94661146, 0.97068864, 0.97275424],
#        dtype=float32))

# %%
parent_comment_map = pickle.load((DATA_PATH/'parent_comment_map.pkl').open('rb'))

# %%
parent_ids = [25642565, 50661263, 2551706, 50656792, 50646159]
all_comment_ids = [j for i in results for j in parent_comment_map[i]]
all_comment_ids
# Out:
# [25807038, 50661315, 2551741, 2551760, 2551787, 2551789, 50658829, 50646212]

# %%
l = '?,'*len(parent_comment_map[2551706])
l[:-1]
# Out:
# '?,?,?,?'

# %%
import sqlite3
DB_NAME = 'StackOverflow.db'
connection = sqlite3.connect(DB_NAME)
c = connection.cursor()

parent_ids = [25642565, 50661263, 2551706, 50656792, 50646159]
all_comment_ids = [j for i in results for j in parent_comment_map[i]]
# all_comment_ids


neighbor_length = '?,' * len(all_comment_ids)
print(neighbor_length)
df = pd.read_sql("SELECT * FROM posts WHERE comment_id IN ({})".format(neighbor_length[:-1]), 
                                 connection, params=tuple(all_comment_ids))
# Out:
# ?,?,?,?,?,?,?,?,

# %%
df
# Out:
#    comment_id  parent_id                                            comment  \
# 0     2551741    2551706  <p>There are some good articles about that her...
# 1     2551760    2551706  <p>The best way to handle this scenario would ...
# 2     2551787    2551706  <p>You have following to choose from:</p> <ol>...
# 3     2551789    2551706  <p>Something like below (the first part just w...
# 4    25807038   25642565  <p>I specified parameter for 'file'</p> <pre><...
# 5    50646212   50646159  <p>Why not wrap your task in a function and ca...
# 6    50658829   50656792  <p>Macros are expanded exactly once, when the ...
# 7    50661315   50661263  <p>This is a definition of a global variable, ...
#
#   title        date  score  tags
# 0  None  2010-03-31      0  None
# 1  None  2010-03-31      0  None
# 2  None  2010-03-31      0  None
# 3  None  2010-03-31      1  None
# 4  None  2014-09-12      0  None
# 5  None  2018-06-01      3  None
# 6  None  2018-06-02      0  None
# 7  None  2018-06-02      3  None

# %%
x = 25642565

df = pd.read_sql("SELECT * FROM posts WHERE comment_id = 36698259;", 
                                 connection)

# %%
df
# Out:
#    comment_id parent_id                                            comment  \
# 0    36698259      None  <p>I would like to sort this list:</p> <p><cod...
#
#                                     title        date  score  \
# 0  Python - How to sort a list of strings  2016-04-18      0
#
#                         tags
# 0  python sorting python-3.x
